# %% [markdown]
# ### Matplotlib & seaborn --> important for interview
# * Plotly ---> very interactive
# * Bokeh ----> less used coz complicated

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
#  Styles for visualization
# plt.style.use('classic')
'''https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html'''

# color code in matplotlib
'''https://matplotlib.org/stable/users/explain/colors/colors.html'''
'''https://matplotlib.org/stable/gallery/color/named_colors.html'''
# Out:
# 'https://matplotlib.org/stable/gallery/color/named_colors.html'

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
plt.scatter(x,y)

# %%
df = pd.DataFrame(np.random.randn(1000),columns=['data'], index=pd.date_range('2020/04/21', periods = 1000))
df.head()
# Out:
#                 data
# 2020-04-21 -0.152463
# 2020-04-22  1.429454
# 2020-04-23  1.006167
# 2020-04-24  0.787707
# 2020-04-25 -0.912435

# %%
df.plot(figsize=(20,8))
# Out:
# <Axes: >

# %%
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x),'--')

# %%
plt.plot(x, np.sin(x),'.-')

# %%
plt.plot(x, np.sin(x),'.')

# %%
plt.plot(x, np.sin(x),':')

# %%
plt.plot(x, np.sin(x),',')

# %%
plt.figure(figsize=(10,5)) #take the canvas for graph/plot
plt.subplot(1,2,1) # 1,2,1 ---> on 1 page, make 2 subparts of that page and access 1st sub-page
plt.plot(x, np.sin(x),'.-')
plt.subplot(1,2,2) # 1,2,1 ---> on 1 page, make 2 subparts of that page and access 2nd sub-page
plt.plot(x, np.cos(x),'.')

# %%
plt.figure(figsize=(10,5)) #take the canvas for graph/plot
# matrix = 2X1
plt.subplot(2,1,1) # 1,2,1 ---> on 1 page, make 2 subparts i.e. 2 rows and access 1st sub-page
plt.plot(x, np.sin(x),'.-')
plt.subplot(2,1,2) # 1,2,1 ---> on 1 page, make 2 subparts i.e. 2 rows  and access 2nd sub-page
plt.plot(x, np.cos(x),'.')

# %%
plt.figure() #take the canvas for graph/plot
# here, matrix canvas will be of 2X2
plt.subplot(2,2,1) # 2,2,1 ---> on canvas make 2 rows, make 2 subparts of divided page and access 1st sub-page
plt.plot(x, np.sin(x),'.-')
plt.subplot(2,2,2) # 2,2,1 ---> on canvas make 2 rows, make 2 subparts of divided page and access 2nd sub-page
plt.plot(x, np.cos(x),'.')
plt.subplot(2,2,3) # 2,2,1 ---> on canvas make 2 rows, make 2 subparts of divided page and access 3rd sub-page
plt.plot(x, np.tan(x),'--')
plt.subplot(2,2,4) # 2,2,1 ---> on canvas make 2 rows, make 2 subparts of divided page and access 4rth sub-page
plt.plot(x, np.tanh(x))

# %%
plt.figure(figsize=(10,11)) #take the canvas for graph/plot
# here, matrix canvas will be of 3X2
plt.subplot(3,2,1) # 2,2,1 ---> on canvas make 2 rows, make 2 subparts of divided page and access 1st sub-page
plt.plot(x, np.sin(x),'.-')
plt.subplot(3,2,2) # 2,2,1 ---> on canvas make 2 rows, make 2 subparts of divided page and access 2nd sub-page
plt.plot(x, np.cos(x),'.')
plt.subplot(3,2,3) # 2,2,1 ---> on canvas make 2 rows, make 2 subparts of divided page and access 3rd sub-page
plt.plot(x, np.tan(x),'--')
plt.subplot(3,2,4) # 2,2,1 ---> on canvas make 2 rows, make 2 subparts of divided page and access 4rth sub-page
plt.plot(x, np.tanh(x))
plt.subplot(3,2,5) # 2,2,1 ---> on canvas make 2 rows, make 2 subparts of divided page and access 3rd sub-page
plt.plot(x, np.tan(x),'--')
plt.subplot(3,2,6) # 2,2,1 ---> on canvas make 2 rows, make 2 subparts of divided page and access 4rth sub-page
plt.plot(x, np.tanh(x))

# %%
plt.plot(x, np.sin(x),'--', color = 'red')

# color code in matplotlib
'''https://matplotlib.org/stable/users/explain/colors/colors.html'''

'''https://matplotlib.org/stable/gallery/color/named_colors.html'''
# Out:
# 'https://matplotlib.org/stable/gallery/color/named_colors.html'

# %% [markdown]
# **`rgb format` ***

# %%
plt.plot(x, np.sin(x),'--', color = (1.0,0.2,0.6))  # rgb format

# %%
plt.plot(x, np.sin(x-0),'--', color = (0.4,0.2,0.4))
plt.xlim(1,15)
plt.ylim(1.5,-1.5)
plt.show()

# %%
plt.plot(x, np.sin(x-0),'--', color = (0.4,0.2,0.4))
plt.xlim(1,15)
plt.ylim(1.5,-1.5)
plt.axis('equal') # to equalize the empty space from all 4 sides of graph  'to make a attractive plot for business team'
plt.show()

# %%
plt.plot(x, np.sin(x-0),'--', color = (0.4,0.2,0.4))
plt.xlim(1,15)
plt.ylim(1.5,-1.5)
plt.grid()
plt.title('This is sinx plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.axis('equal') # to equalize the empty space from all 4 sides of graph  'to make a attractive plot for business team'
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = (0.4,0.2,0.4), label = 'Sinx')
plt.plot(x, np.cos(x-0), color = (0.2,0.5,0.8), label = 'Cosx')
plt.legend()
# plt.xlim(1,15)
# plt.ylim(1.5,-1.5)
plt.grid()
plt.title('This is sinx plot')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# plt.axis('equal') # to equalize the empty space from all 4 sides of graph  'to make a attractive plot for business team'
plt.show()

# %% [markdown]
# ### Histogram
#
# * For continuous data, we will either make histogram or distribution plot

# %%
data = np.random.rand(1000)
data
# Out:
# array([6.25498048e-01, 5.63969364e-01, 5.49469160e-01, 8.96725345e-01,
#        5.42157988e-01, 4.72853580e-01, 8.11776714e-01, 3.12662174e-01,
#        8.15758274e-01, 5.73209750e-01, 2.81568685e-01, 7.94081671e-01,
#        7.82623388e-01, 6.73516792e-01, 4.58973582e-01, 3.56166032e-01,
#        2.94140079e-01, 1.51170154e-01, 9.03211349e-02, 3.65960549e-01,
#        5.35734631e-01, 5.90438446e-01, 8.41845914e-01, 1.23445158e-01,
#        2.48073353e-02, 4.09793148e-01, 3.15575076e-02, 2.79443496e-01,
#        8.06331174e-01, 1.86180481e-01, 3.95303835e-01, 6.08608304e-01,
#        6.93236488e-01, 9.68820030e-01, 1.32472744e-01, 2.11379922e-01,
#        6.62483803e-01, 2.43388228e-01, 2.88027681e-01, 5.68776078e-01,
#        7.19816430e-01, 3.70344021e-01, 1.70007837e-02, 6.63022682e-01,
#        6.10497577e-03, 2.51511723e-01, 6.14228450e-01, 1.03070135e-01,
#        3.11440652e-02, 1.57623987e-01, 9.73654986e-01, 8.70476229e-02,
# ...

# %%
plt.hist(data)
plt.xlabel('x values')
plt.ylabel('Count of x datapoints')
plt.show() # It is best practice to write this line, although without this line, code works

# %% [markdown]
# * bins = smallest unit in which you are dividing data points at x axis. here bin is of 0.2 datapoints. By default there will be 10 bins created i.e. bars are 10 in number.

# %%
plt.hist(data,bins = 25, histtype='step')
plt.xlabel('x values')
plt.ylabel('Count of x datapoints')
plt.show() # It is best practice to write this line, although without this line, code works

# %%
plt.hist(data,bins = 25, histtype='barstacked', rwidth=0.9)
plt.xlabel('x values')
plt.ylabel('Count of x datapoints')
plt.show() # It is best practice to write this line, although without this line, code works

# %%
plt.hist(data,bins = 25, histtype='barstacked', rwidth=0.2, color='green')
plt.xlabel('x values')
plt.ylabel('Count of x datapoints')
plt.show() # It is best practice to write this line, although without this line, code works

# %%
x1 = np.random.rand(50)
y1 = np.random.rand(50)

# %%
plt.figure(figsize=(10,5))
plt.scatter(x1,y1, c = 'g', alpha = 0.4, marker='^')
# alpha parameter show the intensity/opacity of this color
# marker = will shows the shape of the catter plot points ==> *,.,x,X,+,^,>,<
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
a= ['a','b','c','d']
b = np.random.rand(4)

# %%
plt.figure(figsize=(6,3))
plt.bar(a,b, color='teal')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# * horizontal bar plot

# %%
plt.figure(figsize=(6,3))
plt.barh(a,b, color='#FF5733')
plt.xlabel('x')
plt.ylabel('y')
plt.title('categorical and numerical mapping')
plt.show()

# %% [markdown]
# ### 3-D plot

# %%
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')  # to visualize in 3-D
ax.scatter(x,y,z, color = '#FF5733', alpha = 0.7)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
data = pd.read_csv('Bank_churn.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data.plot.scatter(x = 'Age', y = "Balance")
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %% [markdown]
# ### Insights
# * Maximum concentration of balance is in age bucket of 25 to 50 years
# * Maximum balance is at age 40 approx
# * Minimum balance = 0, occues in all ages

# %%
plt.title('Age Distribution')
plt.xlabel('Age')
plt.hist(data['Age'], color='red', histtype='barstacked', rwidth=0.8)
plt.show()

plt.title('Balance Distribution')
plt.xlabel('Balance')
plt.hist(data['Balance'], color='red', histtype='barstacked', rwidth=0.8)
plt.show()

# %%
plt.boxplot(data['Balance'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e5bc1ee350>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e5bc39af90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e5bc32d050>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e5bc2b4550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e5bc20c950>],
#  'means': []}

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1e5bc23c190>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1e5bc067550>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1e5bc0f5cd0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1e5bc169150>}

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# all datasets that seaborn has
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
sns.histplot(tips['total_bill'], kde = True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13032\4271412032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.scatterplot(y = tips['total_bill'], x = tips['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(y = tips['total_bill'], x = tips['tip'], hue = tips['smoker'])
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.relplot(y = tips['total_bill'], x = tips['tip'], hue = tips['smoker'])

# %%
sns.relplot(y = tips['total_bill'], x = tips['tip'], hue = tips['size'])

# %%
sns.relplot(y = tips['total_bill'], x = tips['tip'], style = tips['smoker'], hue=tips['time'])

# %%
sns.barplot(data = tips, x = 'day', y = 'total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data = tips, x = 'day', y = 'total_bill')

# %%
sns.jointplot(data=tips,x = 'total_bill', y='tip')

# %%
sns.jointplot(data=tips,x = 'total_bill', y='tip', kind='reg')
# reg -- regression

# %%
sns.jointplot(data=tips,x = 'total_bill', y='tip', kind='hex', color='red')
# kind can have values==> kde, hist, scatter, hex, reg, resid

# %%
sns.jointplot(data=tips,x = 'total_bill', y='tip', kind='kde', color='red')
# kde --> contour - used in geophysics, weather, earth quack detection, meterological
# kind can have values==> kde, hist, scatter, hex, reg, resid

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='smoker')

# %%
sns.pairplot(tips, hue = 'smoker',palette = 'coolwarm')

# %%
sns.boxplot(data= tips,x ='total_bill',y ='day' )
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(data= tips,x ='total_bill',y ='day', orient='h' )
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(data=tips, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: >

# %%
tips_num = tips[['total_bill','tip','size']]
tips_num
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
tips_num.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data = tips_num.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.countplot(x = 'sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill', y='tip', data = tips, height = 20, aspect = 1)
# aspect will give you zoom out way to see the plot
# this line shows the linear regression line

# %%
sns.catplot(data=tips, x = 'sex', y = 'tip')
